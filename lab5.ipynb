# %%
# !pip install --upgrade pip setuptools wheel Cython numpy==1.23.5

# Step 2: Clone and build scikit-surprise manually
# !git clone https://github.com/NicolasHug/Surprise.git
# %cd Surprise
# !python setup.py install
# %cd ..

# Step 1: Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
from surprise import Dataset, Reader, SVD
from surprise.model_selection import train_test_split, cross_validate
from surprise import accuracy
# Out:
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/dist-packages/scikit_surprise-1.1.4-py3.11-linux-x86_64.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Requirement already satisfied: pip in /usr/local/lib/python3.11/dist-packages (25.0.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (79.0.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (0.45.1)
# Requirement already satisfied: Cython in /usr/local/lib/python3.11/dist-packages (3.0.12)
# Requirement already satisfied: numpy==1.23.5 in /usr/local/lib/python3.11/dist-packages (1.23.5)
# fatal: destination path 'Surprise' already exists and is not an empty directory.
# /content/Surprise
# /usr/local/lib/python3.11/dist-packages/setuptools/config/_apply_pyprojecttoml.py:82: SetuptoolsDeprecationWarning: `project.license` as a TOML table is deprecated
# !!
#
#         ********************************************************************************
#         Please use a simple string containing a SPDX expression for `project.license`. You can also use `project.license-files`. (Both options available on setuptools>=77.0.0).
#
#         By 2026-Feb-18, you need to update your project and remove deprecated calls
#         or your builds will no longer be supported.
#
#         See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#         ********************************************************************************
#
# !!
#   corresp(dist, value, root_dir)
# /usr/local/lib/python3.11/dist-packages/setuptools/config/_apply_pyprojecttoml.py:61: SetuptoolsDeprecationWarning: License classifiers are deprecated.
# !!
#
#         ********************************************************************************
#         Please consider removing the following classifiers in favor of a SPDX license expression:
#
#         License :: OSI Approved :: BSD License
#
#         See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#         ********************************************************************************
#
# !!
#   dist._finalize_license_expression()
# /usr/local/lib/python3.11/dist-packages/setuptools/dist.py:759: SetuptoolsDeprecationWarning: License classifiers are deprecated.
# !!
#
#         ********************************************************************************
#         Please consider removing the following classifiers in favor of a SPDX license expression:
#
#         License :: OSI Approved :: BSD License
#
#         See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#         ********************************************************************************
#
# !!
#   self._finalize_license_expression()
# running install
# /usr/local/lib/python3.11/dist-packages/setuptools/_distutils/cmd.py:90: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.11/dist-packages/setuptools/_distutils/cmd.py:90: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# writing scikit_surprise.egg-info/PKG-INFO
# writing dependency_links to scikit_surprise.egg-info/dependency_links.txt
# writing entry points to scikit_surprise.egg-info/entry_points.txt
# writing requirements to scikit_surprise.egg-info/requires.txt
# writing top-level names to scikit_surprise.egg-info/top_level.txt
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/arrayobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/arrayscalars.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ndarrayobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ndarraytypes.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ufuncobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/arrayobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/arrayscalars.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ndarrayobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ndarraytypes.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ufuncobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/arrayobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/arrayscalars.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ndarrayobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ndarraytypes.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ufuncobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/arrayobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/arrayscalars.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ndarrayobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ndarraytypes.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ufuncobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/arrayobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/arrayscalars.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ndarrayobject.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ndarraytypes.h won't be automatically included in the manifest: the path must be relative
# dependency /usr/local/lib/python3.11/dist-packages/numpy/core/include/numpy/ufuncobject.h won't be automatically included in the manifest: the path must be relative
# reading manifest file 'scikit_surprise.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no previously-included files matching '*.so' found under directory 'surprise'
# adding license file 'LICENSE.md'
# writing manifest file 'scikit_surprise.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# copying surprise/utils.py -> build/lib.linux-x86_64-cpython-311/surprise
# copying surprise/dataset.py -> build/lib.linux-x86_64-cpython-311/surprise
# copying surprise/builtin_datasets.py -> build/lib.linux-x86_64-cpython-311/surprise
# copying surprise/__main__.py -> build/lib.linux-x86_64-cpython-311/surprise
# copying surprise/reader.py -> build/lib.linux-x86_64-cpython-311/surprise
# copying surprise/dump.py -> build/lib.linux-x86_64-cpython-311/surprise
# copying surprise/trainset.py -> build/lib.linux-x86_64-cpython-311/surprise
# copying surprise/accuracy.py -> build/lib.linux-x86_64-cpython-311/surprise
# copying surprise/__init__.py -> build/lib.linux-x86_64-cpython-311/surprise
# copying surprise/model_selection/validation.py -> build/lib.linux-x86_64-cpython-311/surprise/model_selection
# copying surprise/model_selection/search.py -> build/lib.linux-x86_64-cpython-311/surprise/model_selection
# copying surprise/model_selection/split.py -> build/lib.linux-x86_64-cpython-311/surprise/model_selection
# copying surprise/model_selection/__init__.py -> build/lib.linux-x86_64-cpython-311/surprise/model_selection
# copying surprise/prediction_algorithms/baseline_only.py -> build/lib.linux-x86_64-cpython-311/surprise/prediction_algorithms
# copying surprise/prediction_algorithms/random_pred.py -> build/lib.linux-x86_64-cpython-311/surprise/prediction_algorithms
# copying surprise/prediction_algorithms/predictions.py -> build/lib.linux-x86_64-cpython-311/surprise/prediction_algorithms
# copying surprise/prediction_algorithms/algo_base.py -> build/lib.linux-x86_64-cpython-311/surprise/prediction_algorithms
# copying surprise/prediction_algorithms/knns.py -> build/lib.linux-x86_64-cpython-311/surprise/prediction_algorithms
# copying surprise/prediction_algorithms/__init__.py -> build/lib.linux-x86_64-cpython-311/surprise/prediction_algorithms
# copying surprise/similarities.pyx -> build/lib.linux-x86_64-cpython-311/surprise
# copying surprise/prediction_algorithms/co_clustering.pyx -> build/lib.linux-x86_64-cpython-311/surprise/prediction_algorithms
# copying surprise/prediction_algorithms/matrix_factorization.pyx -> build/lib.linux-x86_64-cpython-311/surprise/prediction_algorithms
# copying surprise/prediction_algorithms/optimize_baselines.pyx -> build/lib.linux-x86_64-cpython-311/surprise/prediction_algorithms
# copying surprise/prediction_algorithms/slope_one.pyx -> build/lib.linux-x86_64-cpython-311/surprise/prediction_algorithms
# running build_ext
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/surprise
# copying build/lib.linux-x86_64-cpython-311/surprise/utils.py -> build/bdist.linux-x86_64/egg/surprise
# copying build/lib.linux-x86_64-cpython-311/surprise/dataset.py -> build/bdist.linux-x86_64/egg/surprise
# copying build/lib.linux-x86_64-cpython-311/surprise/builtin_datasets.py -> build/bdist.linux-x86_64/egg/surprise
# copying build/lib.linux-x86_64-cpython-311/surprise/similarities.pyx -> build/bdist.linux-x86_64/egg/surprise
# copying build/lib.linux-x86_64-cpython-311/surprise/__main__.py -> build/bdist.linux-x86_64/egg/surprise
# copying build/lib.linux-x86_64-cpython-311/surprise/reader.py -> build/bdist.linux-x86_64/egg/surprise
# copying build/lib.linux-x86_64-cpython-311/surprise/dump.py -> build/bdist.linux-x86_64/egg/surprise
# copying build/lib.linux-x86_64-cpython-311/surprise/trainset.py -> build/bdist.linux-x86_64/egg/surprise
# copying build/lib.linux-x86_64-cpython-311/surprise/accuracy.py -> build/bdist.linux-x86_64/egg/surprise
# creating build/bdist.linux-x86_64/egg/surprise/model_selection
# copying build/lib.linux-x86_64-cpython-311/surprise/model_selection/validation.py -> build/bdist.linux-x86_64/egg/surprise/model_selection
# copying build/lib.linux-x86_64-cpython-311/surprise/model_selection/search.py -> build/bdist.linux-x86_64/egg/surprise/model_selection
# copying build/lib.linux-x86_64-cpython-311/surprise/model_selection/split.py -> build/bdist.linux-x86_64/egg/surprise/model_selection
# copying build/lib.linux-x86_64-cpython-311/surprise/model_selection/__init__.py -> build/bdist.linux-x86_64/egg/surprise/model_selection
# copying build/lib.linux-x86_64-cpython-311/surprise/similarities.cpython-311-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/egg/surprise
# copying build/lib.linux-x86_64-cpython-311/surprise/__init__.py -> build/bdist.linux-x86_64/egg/surprise
# creating build/bdist.linux-x86_64/egg/surprise/prediction_algorithms
# copying build/lib.linux-x86_64-cpython-311/surprise/prediction_algorithms/baseline_only.py -> build/bdist.linux-x86_64/egg/surprise/prediction_algorithms
# copying build/lib.linux-x86_64-cpython-311/surprise/prediction_algorithms/co_clustering.pyx -> build/bdist.linux-x86_64/egg/surprise/prediction_algorithms
# copying build/lib.linux-x86_64-cpython-311/surprise/prediction_algorithms/random_pred.py -> build/bdist.linux-x86_64/egg/surprise/prediction_algorithms
# copying build/lib.linux-x86_64-cpython-311/surprise/prediction_algorithms/slope_one.cpython-311-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/egg/surprise/prediction_algorithms
# copying build/lib.linux-x86_64-cpython-311/surprise/prediction_algorithms/predictions.py -> build/bdist.linux-x86_64/egg/surprise/prediction_algorithms
# copying build/lib.linux-x86_64-cpython-311/surprise/prediction_algorithms/co_clustering.cpython-311-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/egg/surprise/prediction_algorithms
# copying build/lib.linux-x86_64-cpython-311/surprise/prediction_algorithms/matrix_factorization.cpython-311-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/egg/surprise/prediction_algorithms
# copying build/lib.linux-x86_64-cpython-311/surprise/prediction_algorithms/matrix_factorization.pyx -> build/bdist.linux-x86_64/egg/surprise/prediction_algorithms
# copying build/lib.linux-x86_64-cpython-311/surprise/prediction_algorithms/algo_base.py -> build/bdist.linux-x86_64/egg/surprise/prediction_algorithms
# copying build/lib.linux-x86_64-cpython-311/surprise/prediction_algorithms/knns.py -> build/bdist.linux-x86_64/egg/surprise/prediction_algorithms
# copying build/lib.linux-x86_64-cpython-311/surprise/prediction_algorithms/__init__.py -> build/bdist.linux-x86_64/egg/surprise/prediction_algorithms
# copying build/lib.linux-x86_64-cpython-311/surprise/prediction_algorithms/optimize_baselines.pyx -> build/bdist.linux-x86_64/egg/surprise/prediction_algorithms
# copying build/lib.linux-x86_64-cpython-311/surprise/prediction_algorithms/slope_one.pyx -> build/bdist.linux-x86_64/egg/surprise/prediction_algorithms
# copying build/lib.linux-x86_64-cpython-311/surprise/prediction_algorithms/optimize_baselines.cpython-311-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/egg/surprise/prediction_algorithms
# byte-compiling build/bdist.linux-x86_64/egg/surprise/utils.py to utils.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/surprise/dataset.py to dataset.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/surprise/builtin_datasets.py to builtin_datasets.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/surprise/__main__.py to __main__.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/surprise/reader.py to reader.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/surprise/dump.py to dump.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/surprise/trainset.py to trainset.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/surprise/accuracy.py to accuracy.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/surprise/model_selection/validation.py to validation.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/surprise/model_selection/search.py to search.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/surprise/model_selection/split.py to split.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/surprise/model_selection/__init__.py to __init__.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/surprise/__init__.py to __init__.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/surprise/prediction_algorithms/baseline_only.py to baseline_only.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/surprise/prediction_algorithms/random_pred.py to random_pred.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/surprise/prediction_algorithms/predictions.py to predictions.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/surprise/prediction_algorithms/algo_base.py to algo_base.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/surprise/prediction_algorithms/knns.py to knns.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/surprise/prediction_algorithms/__init__.py to __init__.cpython-311.pyc
# creating stub loader for surprise/similarities.cpython-311-x86_64-linux-gnu.so
# creating stub loader for surprise/prediction_algorithms/matrix_factorization.cpython-311-x86_64-linux-gnu.so
# creating stub loader for surprise/prediction_algorithms/optimize_baselines.cpython-311-x86_64-linux-gnu.so
# creating stub loader for surprise/prediction_algorithms/slope_one.cpython-311-x86_64-linux-gnu.so
# creating stub loader for surprise/prediction_algorithms/co_clustering.cpython-311-x86_64-linux-gnu.so
# byte-compiling build/bdist.linux-x86_64/egg/surprise/similarities.py to similarities.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/surprise/prediction_algorithms/matrix_factorization.py to matrix_factorization.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/surprise/prediction_algorithms/optimize_baselines.py to optimize_baselines.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/surprise/prediction_algorithms/slope_one.py to slope_one.cpython-311.pyc
# byte-compiling build/bdist.linux-x86_64/egg/surprise/prediction_algorithms/co_clustering.py to co_clustering.cpython-311.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying scikit_surprise.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying scikit_surprise.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying scikit_surprise.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying scikit_surprise.egg-info/entry_points.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying scikit_surprise.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying scikit_surprise.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# writing build/bdist.linux-x86_64/egg/EGG-INFO/native_libs.txt
# zip_safe flag not set; analyzing archive contents...
# surprise.__pycache__.similarities.cpython-311: module references __file__
# surprise.prediction_algorithms.__pycache__.co_clustering.cpython-311: module references __file__
# surprise.prediction_algorithms.__pycache__.matrix_factorization.cpython-311: module references __file__
# surprise.prediction_algorithms.__pycache__.optimize_baselines.cpython-311: module references __file__
# surprise.prediction_algorithms.__pycache__.slope_one.cpython-311: module references __file__
# creating 'dist/scikit_surprise-1.1.4-py3.11-linux-x86_64.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing scikit_surprise-1.1.4-py3.11-linux-x86_64.egg
# removing '/usr/local/lib/python3.11/dist-packages/scikit_surprise-1.1.4-py3.11-linux-x86_64.egg' (and everything under it)
# creating /usr/local/lib/python3.11/dist-packages/scikit_surprise-1.1.4-py3.11-linux-x86_64.egg
# Extracting scikit_surprise-1.1.4-py3.11-linux-x86_64.egg to /usr/local/lib/python3.11/dist-packages
# Adding scikit-surprise 1.1.4 to easy-install.pth file
# Installing surprise script to /usr/local/bin
#
# Installed /usr/local/lib/python3.11/dist-packages/scikit_surprise-1.1.4-py3.11-linux-x86_64.egg
# Processing dependencies for scikit-surprise==1.1.4
# Searching for scipy==1.14.1
# Best match: scipy 1.14.1
# Adding scipy 1.14.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for numpy==1.23.5
# Best match: numpy 1.23.5
# Adding numpy 1.23.5 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing f2py3 script to /usr/local/bin
# Installing f2py3.11 script to /usr/local/bin
#
# Using /usr/local/lib/python3.11/dist-packages
# Searching for joblib==1.4.2
# Best match: joblib 1.4.2
# Adding joblib 1.4.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.11/dist-packages
# Finished processing dependencies for scikit-surprise==1.1.4
# /content

# %%
file_path = 'drive/MyDrive/datasets/amazon_review.csv'
df = pd.read_csv(file_path, header=None, names=['userId', 'itemId', 'rating', 'timestamp'])
df = df[['userId', 'itemId', 'rating']]
df.dropna(inplace=True)

print(df.head())
# Out:
#            userId      itemId  rating
# 0   AKM1MP6P0OYPR  0132793040     5.0
# 1  A2CX7LUOHB2NDG  0321732944     5.0
# 2  A2NWSAGRHCP8N5  0439886341     1.0
# 3  A2WNBOD3WNDNKT  0439886341     3.0
# 4  A1GI0U4ZRJA8WN  0439886341     1.0

# %%
min_ratings = 5
df = df.groupby("userId").filter(lambda x: len(x) >= min_ratings)

# %%
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(df[["userId", "itemId", "rating"]], reader)

# %%
from surprise.model_selection import train_test_split, GridSearchCV
param_grid = {
    "n_epochs": [10, 20],
    "lr_all": [0.002, 0.005],
    "reg_all": [0.02, 0.1]
}

gs = GridSearchCV(SVD, param_grid, measures=["rmse", "mae"], cv=3)
gs.fit(data)

print("Best RMSE score:", gs.best_score["rmse"])
print("Best parameters:", gs.best_params["rmse"])
# Out:
# Best RMSE score: 1.135482549666239
# Best parameters: {'n_epochs': 20, 'lr_all': 0.005, 'reg_all': 0.1}

# %%
model = gs.best_estimator["rmse"]
trainset = data.build_full_trainset()
model.fit(trainset)

# %%
trainset_split, testset_split = train_test_split(data, test_size=0.2)
model.fit(trainset_split)
predictions = model.test(testset_split)
print("RMSE:", accuracy.rmse(predictions))
print("MAE:", accuracy.mae(predictions))
# Out:
# RMSE: 1.1292
# RMSE: 1.1291869472355403
# MAE:  0.8504
# MAE: 0.8504054680960125

# %%
def get_unseen_items(uid, trainset):
    if uid not in trainset._raw2inner_id_users:
        return []
    seen = set(j for (j, _) in trainset.ur[trainset.to_inner_uid(uid)])
    unseen = set(trainset.all_items()) - seen
    return [trainset.to_raw_iid(iid) for iid in unseen]

def recommend_top_n(model, trainset, uid, n=5):
    unseen_items = get_unseen_items(uid, trainset)
    predictions = [model.predict(uid, iid) for iid in unseen_items]
    top_n = sorted(predictions, key=lambda x: x.est, reverse=True)[:n]
    return [(pred.iid, pred.est) for pred in top_n]

example_user = df["userId"].iloc[0]
recommendations = recommend_top_n(model, trainset, example_user, n=5)

print(f"\n🎯 Top 5 recommendations for user {example_user}:")
for item_id, rating in recommendations:
    print(f"Item ID: {item_id}, Predicted Rating: {rating:.2f}")
# Out:
# 🎯 Top 5 recommendations for user A3J3BRHTDRFJ2G:
# Item ID: B003U4VIWW, Predicted Rating: 4.12
# Item ID: B007BXD6DW, Predicted Rating: 4.03
# Item ID: B009ACD844, Predicted Rating: 4.03
# Item ID: B0007Y791C, Predicted Rating: 4.02
# Item ID: B00FA1Y65O, Predicted Rating: 4.02
